# %%
from scripts.parser_procedure import Parser
#from scripts.parser_entities import Tree

# %%
#!pytest -q

# %%
input_string = "ra"
p = Parser()
p.load_params(level=1)
res = p.parse(input_string)
print(res, p.buff.tree)
# Out:
# Parsing string 'ra' as 'ra'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# -> Comparing r with first mask 'C'
# => Assigned stances [0, 0, 0]
# Working with 'a'
# -> Comparing a with first mask '̲CVCV'
# -> Comparing a with first mask '̲CV'
# -> Comparing a with first mask '̲C'
# -> Comparing a with second mask 'V'
# => Assigned stances [0, 0, 1]
# -> Caret moved at [0, 0, 0]
# -> Caret moved at [0, 0, 1]
# True T[2, 1]
# └─N(0): ra
#   ├─N(1):
#   │ ├─N(5):
#   │ └─N(6):
#   ├─N(2): ra
#   │ ├─N(7): r
#   │ └─N(8): a
#   ├─N(3):
#   │ ├─N(9):
#   │ └─N(10):
#   └─N(4):
#     ├─N(11):
#     └─N(12):

# %%
tree = p.buff.tree
tree.embed_compound(1)
print(tree)
# Out:
# T[2, 1]
# └─N(0): ra
#   ├─N(1):
#     ⤷─N(0):
#       ├─N(1):
#       └─N(2):
#   │ ├─N(5):
#   │ └─N(6):
#   ├─N(2): ra
#   │ ├─N(7): r
#   │ └─N(8): a
#   ├─N(3):
#   │ ├─N(9):
#   │ └─N(10):
#   └─N(4):
#     ├─N(11):
#     └─N(12):
