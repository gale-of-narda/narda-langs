# %%
from scripts.parser_procedure import Processor
#from scripts.parser_entities import Tree, Element
#from scripts.parser_dataclasses import Symbol, Token

# %%
instr = "akakakak" #-lág–ırú-mán<àve–sýd> <èda>dóro ı̀me: hréagu-sán nēı dāa
prc = Processor(max_level=0)
prc.process(instr)
# Out:
# [INFO] Parsing akakakak
# [DEBUG] Comps: [(None, 0), (None, 0)]
# [DEBUG] -> Fitting a to the 1st mask '?CVCV'
# [DEBUG] Comps: [(1, 0), None]
# [DEBUG] -> Fitting a to the 1st mask '?C̲V' → '?CV̲'
# [DEBUG] Comps: [None, (0, 0)]
# [DEBUG] -> Fitting a to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [001|000|0] to a
# [DEBUG] Comps: [(None, 0), (None, 0)]
# [DEBUG] -> Fitting k to the 1st mask '?CVCV'
# [DEBUG] Comps: [None, (0, 0)]
# [DEBUG] -> Inserting w with stance [000|000|0]
# [DEBUG] -> Fitting k to the 2nd mask 'C̲V' → 'C̲V'
# [DEBUG] Comps: [(0, 0), None]
# [DEBUG] -> Fitting k to the 1st mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [010|000|0] to k
# [DEBUG] Comps: [(None, 0), (None, 0)]
# [DEBUG] -> Fitting a to the 1st mask '?CVCV'
# [DEBUG] Comps: [None, (1, 0)]
# [DEBUG] -> Fitting a to the 2nd mask 'C̲V' → 'CV̲'
# [DEBUG] Comps: [None, (0, 0)]
# [DEBUG] -> Fitting a to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [011|000|0] to a
# [DEBUG] Comps: [(None, 0), (None, 0)]
# [DEBUG] -> Fitting k to the 1st mask '?CVCV'
# [DEBUG] Comps: [None, (0, 1)]
# [DEBUG] -> Fitting k to the 2nd mask 'CV̲' → 'C̲V'
# [DEBUG] Comps: [(0, 0), None]
# [DEBUG] -> Fitting k to the 1st mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [010|010|0] to k
# [DEBUG] Comps: [(None, 0), (None, 0)]
# [DEBUG] -> Fitting a to the 1st mask '?CVCV'
# [DEBUG] Comps: [None, (1, 1)]
# [DEBUG] -> Fitting a to the 2nd mask 'C̲V' → 'CV̲'
# [DEBUG] Comps: [None, (0, 0)]
# [DEBUG] -> Fitting a to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [011|010|0] to a
# [DEBUG] Comps: [(None, 0), (None, 0)]
# [DEBUG] -> Fitting k to the 1st mask '?CVCV'
# [DEBUG] Comps: [None, None]
# [DEBUG] Comps: [None, None]
# [WARNING] => Could not decide '?C̲V'—'CV' for k
# [INFO] Failed to parse akakakak
# False

# %%
print(f"Level 1: {prc.get_stances(lvl=1)}")
print(f"Level 0: {prc.get_stances(lvl=0)}")
prc.draw_tree(0, all_nodes=True)
prc.draw_tree(1, all_nodes=True)
# Out:
# Level 1: []
# Level 0: [[000|000|0], [001|000|0], [010|000|0], [011|000|0], [010|010|0], [011|010|0]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 print(f"Level 1: {prc.get_stances(lvl=1)}")
#       2 print(f"Level 0: {prc.get_stances(lvl=0)}")
# ----> 3 prc.draw_tree(0, all_nodes=True)
#       4 prc.draw_tree(1, all_nodes=True)
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:93, in Processor.draw_tree(self, tree, features, all_nodes)
#      91     tree = self.trees[0][-1]
#      92 elif isinstance(tree, int):
# ---> 93     tree = self.trees[tree][-1]
#      95 st = str(tree)
#      97 if tree.stance:
#
# IndexError: list index out of range

# %%
prc.masker.masks[0][0][1][0].masks[1].lemb
# Out:
# 1
