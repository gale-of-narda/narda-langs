# %%
from scripts.parser_procedure import Processor
#from scripts.parser_entities import Tree, Element
#from scripts.parser_dataclasses import Symbol, Token

# %%
instr = "mán-àve><sýd"
prc = Processor(max_level=0)
prc.process(instr, verbose=True)
# Out:
# [INFO] Parsing mán-àve><sýd
# [DEBUG] -> Fitting m to the 1st mask '?CVCV'
# [DEBUG] -> Fitting m to the 1st mask '?C̲V' → '?C̲V'
# [DEBUG] -> Fitting m to the 1st mask '?C̲' → '?C̲'
# [DEBUG] => Assigned the stance [000|000|0] to m
# [DEBUG] -> Fitting á to the 1st mask '?CVCV'
# [DEBUG] -> Fitting á to the 1st mask '?C̲V' → '?CV̲'
# [DEBUG] -> Fitting á to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [001|000|0] to á
# [DEBUG] -> Breaker count at level 0, depth 0 increased to 1
# [DEBUG] -> Shifted m from [000|000|0] to [010|000|0]
# [DEBUG] -> Shifted á from [001|000|0] to [011|000|0]
# [DEBUG] Filling for '?C'—'V' at [m, á]
# [DEBUG] Filling for 'C'—'V̲' at [m, á]
# [DEBUG] -> Fitting n to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting n to the 1st mask '?V̲C' → '?VC̲'
# [DEBUG] -> Fitting n to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [100|000|0] to n
# [DEBUG] -> Depth at level 0 increased to 1
# [DEBUG] -> Breaker count at level 0, depth 1 increased to 1
# [DEBUG] Filling for '?C'—'V' at []
# [DEBUG] Filling for 'C'—'V' at []
# [DEBUG] -> Fitting à to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting à to the 1st mask '?V̲C' → '?V̲C'
# [DEBUG] -> Fitting à to the 1st mask '?V̲' → '?V̲'
# [DEBUG] => Assigned the stance [101|000|1] to à
# [DEBUG] -> Fitting v to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting v to the 1st mask '?V̲C' → '?VC̲'
# [DEBUG] -> Fitting v to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [100|000|1] to v
# [DEBUG] -> Fitting e to the 2nd mask '?VCVC'
# [DEBUG] Filling for '?V'—'C̲' at [à, v]
# [DEBUG] -> Fitting e to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting e to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|000|1] to e
# [DEBUG] Filling for '?V'—'C' at [à, v, e]
# [DEBUG] Filling for 'V̲'—'C' at [à, v, e]
# [DEBUG] Validating [à, v, e]
# [DEBUG] -> Fitting à to the 2nd mask '?VCVC'
# [DEBUG] Filling for '?V'—'C̲' at [m, á, n, à̲ve]
# [DEBUG] -> Inserting ə with stance [101|000|0]
# [DEBUG] -> Fitting à to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting à to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|000|0] to à̲vəe
# [DEBUG] -> Depth at level 0 decreased to 0
# [DEBUG] -> Depth at level 0 increased to 1
# [DEBUG] -> Fitting s to the 1st mask '?CVCV'
# [DEBUG] -> Fitting s to the 1st mask '?C̲V' → '?C̲V'
# [DEBUG] -> Fitting s to the 1st mask '?C̲' → '?C̲'
# [DEBUG] => Assigned the stance [000|000|1] to s
# [DEBUG] -> Fitting ý to the 1st mask '?CVCV'
# [DEBUG] -> Fitting ý to the 1st mask '?C̲V' → '?CV̲'
# [DEBUG] -> Fitting ý to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [001|000|1] to ý
# [DEBUG] -> Breaker count at level 0, depth 1 increased to 1
# [DEBUG] -> Shifted s from [000|000|1] to [010|000|1]
# [DEBUG] -> Shifted ý from [001|000|1] to [011|000|1]
# [DEBUG] Filling for '?C'—'V' at [s, ý]
# [DEBUG] Filling for 'C'—'V̲' at [s, ý]
# [DEBUG] -> Fitting d to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting d to the 1st mask '?V̲C' → '?VC̲'
# [DEBUG] -> Fitting d to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [100|000|1] to d
# [DEBUG] Filling for '?V'—'C̲' at [s, ý, d]
# [DEBUG] Filling for 'V'—'C' at [s, ý, d]
# [DEBUG] Validating [s, ý, d]
# [DEBUG] -> Fitting s to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting s to the 2nd mask 'V̲C' → 'VC̲'
# [DEBUG] -> Fitting s to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [110|000|0] to s̲ýd
# [DEBUG] -> Depth at level 0 decreased to 0
# [DEBUG] Filling for '?V'—'C' at [m, á, ə, n, à̲vəe, s̲ýd]
# [DEBUG] Filling for 'V'—'C̲' at [m, á, ə, n, à̲vəe, s̲ýd]
# [DEBUG] Validating [m, á, ə, n, à̲vəe, s̲ýd]
# [INFO] Successfully parsed mán-àve><sýd as [máənàs]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 instr = "mán-àve><sýd"
#       2 prc = Processor(max_level=0)
# ----> 3 prc.process(instr, verbose=True)
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:74, in Processor.process(self, instr, verbose)
#      72 tree = Tree(self.grules.struct[lvl], lvl)
#      73 self.trees[lvl].append(tree)
# ---> 74 self.interpreter.apply(es, tree)
#      75 if self.max_level is None or self.max_level >= lvl:
#      76     self.interpreter.determine_ctype(tree)
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:933, in Interpreter.apply(self, elems, tree)
#     931     base_node = tree.get_nodes(e.stance)
#     932     tree.embed_complex(base_node)
# --> 933     self.apply(e.content, base_node.complexes[-1])
#     935 if e.level > 0:
#     936     sep = self.prc.alphabet.separators[e.level - 1]
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:939, in Interpreter.apply(self, elems, tree)
#     937     else:
#     938         sep = ""
# --> 939     tree.set_element(e, sep, set_all=True)
#     941 return
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_entities.py:623, in Tree.set_element(self, e, sep, set_all)
#     621 for s in struct[: len(e.stance.pos) + 1]:
#     622     node = self.get_nodes(e.stance.copy(cursor + s))
# --> 623     node.map_element(e)
#     624     node.sep = sep
#     625     cursor += s
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_entities.py:667, in Node.map_element(self, e)
#     665     self.content.append(e)
#     666 else:
# --> 667     raise Exception(f"Tried to rewrite the content of terminal node {self}")
#
# Exception: Tried to rewrite the content of terminal node N(10): à

# %%
print(f"Level 1: {prc.get_stances(lvl=1)}")
print(f"Level 0: {prc.get_stances(lvl=0)}")
prc.draw_tree(0, all_nodes=True)
prc.draw_tree(1, all_nodes=True)
# Out:
# Level 1: [[||0]]
# Level 0: [[000|000|0], [001|000|0], [010|000|0], [011|000|0]]
# T[2, 1]: Proform
# └─N(0): wara
#   └─N(1): wa
#   │ └─N(5): w
#   │ └─N(6): a
#   └─N(2): ra
#   │ └─N(7): r
#   │ └─N(8): a
#   └─N(3):
#   │ └─N(9):
#   │ └─N(10):
#   └─N(4):
#     └─N(11):
#     └─N(12):
#
# T[1, 1]: Undefined composition type
# └─N(0): wara
#   └─N(1):
#   │ └─N(3):
#   │ └─N(4):
#   └─N(2):
#     └─N(5):
#     └─N(6):
