# %%
from scripts.parser_procedure import Processor
#from scripts.parser_entities import Tree, Element
#from scripts.parser_dataclasses import Symbol, Token

# %%
instr = "#āe"
prc = Processor(max_level=1)
prc.process(instr)
# Out:
# [INFO] Parsing #āe
# [DEBUG] -> Fitting # to the 1st mask '?CVCV'
# [DEBUG] -> Fitting # to the 2nd mask 'C̲V' → 'C̲V'
# [DEBUG] -> Fitting # to the 1st mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [010|000|0] to #
# [DEBUG] -> Fitting ā to the 1st mask '?CVCV'
# [DEBUG] -> Fitting ā to the 2nd mask 'C̲V' → 'CV̲'
# [DEBUG] -> Fitting ā to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [011|000|0] to ā
# [DEBUG] -> Breaker count at level 0, depth 0 increased to 2
# [DEBUG] -> Fitting e to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting e to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting e to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|000|0] to e
# [DEBUG] -> Inserting w with stance [110|000|0]
# [WARNING] => Could not decide '(ao)?e'—'(yu)?ı' for #āe̲w
# [INFO] Failed to parse #āe
# False

# %%
print(f"Level 1: {prc.get_stances(lvl=1)}")
print(f"Level 0: {prc.get_stances(lvl=0)}")
prc.draw_tree(0, all_nodes=True)
prc.draw_tree(1, all_nodes=True)
# Out:
# Level 1: [[00|00|0]]
# Level 0: [[010|000|0], [011|000|0]]
# T[2, 1]: Proform
# └─N(0): #e
#   └─N(1):
#   │ └─N(5):
#   │ └─N(6):
#   └─N(2): #e
#   │ └─N(7): #
#   │ └─N(8): e
#   └─N(3):
#   │ └─N(9):
#   │ └─N(10):
#   └─N(4):
#     └─N(11):
#     └─N(12):
#
# T[1, 1]: Predicate-only
# └─N(0): #̲e
#   └─N(1): #̲e
#   │ └─N(3): #̲e
#   │ └─N(4):
#   └─N(2):
#     └─N(5):
#     └─N(6):
