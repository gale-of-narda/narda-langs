# %%
import logging

from scripts.parser_procedure import Processor
# from scripts.parser_entities import Tree, Element
# from scripts.parser_dataclasses import Symbol, Token

logging.basicConfig(level="DEBUG", format="%(message)s", datefmt="[%X]")

# %%
instr = "térsus: lāuı ránom obrúnus: lāuı déro nōus." # "lāuı ránom obrúnus: lāuı déro nōus;; hólos apáurus" 
prc = Processor()
prc.process(instr, verbose=True)
# Out:
# Parsing 'térsus: lāuı ránom obrúnus: lāuı déro nōus.'
# [L0|D0] Fitting 't' to the 1st mask '?CVCV'
# [L0|D0] Fitting 't' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 't' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 't' with stance [000|000|0]
# [L0|D0] Fitting 'é' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'é' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'é' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'é' with stance [001|000|0]
# [L0|D0] Breaker count increased to 1
# [L0|D0] Shifted t from [000|000|0] to [010|000|0]
# [L0|D0] Shifted é from [001|000|0] to [011|000|0]
# [L0|D0] Fitting 'r' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'r' to the 1st mask '?V̲C' → '?VC̲'
# [L0|D0] Fitting 'r' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 'r' with stance [100|000|0]
# [L0|D0] Fitting 's' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 's' to the 1st mask '?VC̲' → '?VC̲'
# [L0|D0] Fitting 's' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 's' with stance [100|001|0]
# [L0|D0] Fitting 'u' to the 2nd mask '?VC!VC'
# [L0|D0] Inserting ə with stance [101|000|0]
# [L0|D0] Fitting 'u' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'u' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'u' with stance [111|000|0]
# [L0|D0] Fitting 's' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 's' to the 2nd mask '!V̲C' → '!VC̲'
# [L0|D0] Fitting 's' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 's' with stance [110|000|0]
# [L1|D0] Fitting 'téərsu̲s' to the 2nd mask '(y̲u̲)?ı' → '(y̲u̲)?ı'
# [L1|D0] Fitting 'téərsu̲s' to the 1st mask '(y̲u̲)' → '(y̲u̲)'
# [L1|D0] Fit 'téərsu̲s' with stance [10|00|0]
# [L1|D0] Depth at level 1 increased to 1
# [L0|D0] Fitting 'l' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'l' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 'l' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 'l' with stance [000|000|0]
# [L0|D0] Fitting 'ā' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'ā' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'ā' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'ā' with stance [001|000|0]
# [L0|D0] Breaker count increased to 2
# [L0|D0] Shifted l from [000|000|0] to [010|000|0]
# [L0|D0] Shifted ā from [001|000|0] to [011|000|0]
# [L0|D0] Fitting 'u' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'u' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'u' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'u' with stance [111|000|0]
# [L0|D0] Fitting 'ı' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'ı' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'ı' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'ı' with stance [111|001|0]
# [L0|D0] Inserting w with stance [110|000|0]
# [L1|D1] Fitting 'lāu̲ıw' to the 2nd mask '(y̲u̲)?ı' → '(y̲u̲)?ı'
# [L1|D1] Fitting 'lāu̲ıw' to the 1st mask '(y̲u̲)' → '(y̲u̲)'
# [L1|D1] Fit 'lāu̲ıw' with stance [10|00|1]
# [L0|D0] Fitting 'r' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'r' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 'r' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 'r' with stance [000|000|0]
# [L0|D0] Fitting 'á' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'á' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'á' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'á' with stance [001|000|0]
# [L0|D0] Breaker count increased to 1
# [L0|D0] Shifted r from [000|000|0] to [010|000|0]
# [L0|D0] Shifted á from [001|000|0] to [011|000|0]
# [L0|D0] Fitting 'n' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'n' to the 1st mask '?V̲C' → '?VC̲'
# [L0|D0] Fitting 'n' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 'n' with stance [100|000|0]
# [L0|D0] Fitting 'o' to the 2nd mask '?VC!VC'
# [L0|D0] Inserting ə with stance [101|000|0]
# [L0|D0] Fitting 'o' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'o' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'o' with stance [111|000|0]
# [L0|D0] Fitting 'm' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'm' to the 2nd mask '!V̲C' → '!VC̲'
# [L0|D0] Fitting 'm' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 'm' with stance [110|000|0]
# [L1|D1] Fitting 'ráəno̲m' to the 1st mask '!(a̲o̲)?e' → '!(a̲o̲)?e'
# [L1|D1] Fitting 'ráəno̲m' to the 1st mask '!(a̲o̲)' → '!(a̲o̲)'
# [L1|D1] Fit 'ráəno̲m' with stance [00|00|1]
# [L0|D0] Fitting 'o' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'o' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'o' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'o' with stance [001|000|0]
# [L0|D0] Fitting 'b' to the 1st mask '?CVCV'
# [L0|D0] Inserting w with stance [000|000|0]
# [L0|D0] Fitting 'b' to the 2nd mask 'C̲V' → 'C̲V'
# [L0|D0] Fitting 'b' to the 1st mask 'C̲' → 'C̲'
# [L0|D0] Fit 'b' with stance [010|000|0]
# [L0|D0] Fitting 'r' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'r' to the 2nd mask 'C̲V' → 'C̲V'
# [L0|D0] Fitting 'r' to the 1st mask 'C̲' → 'C̲'
# [L0|D0] Fit 'r' with stance [010|001|0]
# [L0|D0] Fitting 'ú' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'ú' to the 2nd mask 'C̲V' → 'CV̲'
# [L0|D0] Fitting 'ú' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'ú' with stance [011|000|0]
# [L0|D0] Breaker count increased to 1
# [L0|D0] Fitting 'n' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'n' to the 1st mask '?V̲C' → '?VC̲'
# [L0|D0] Fitting 'n' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 'n' with stance [100|000|0]
# [L0|D0] Fitting 'u' to the 2nd mask '?VC!VC'
# [L0|D0] Inserting ə with stance [101|000|0]
# [L0|D0] Fitting 'u' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'u' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'u' with stance [111|000|0]
# [L0|D0] Fitting 's' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 's' to the 2nd mask '!V̲C' → '!VC̲'
# [L0|D0] Fitting 's' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 's' with stance [110|000|0]
# [L1|D1] Fitting 'wobrúənu̲s' to the 2nd mask '(y̲u̲)?ı' → '(y̲u̲)?ı'
# [L1|D1] Fitting 'wobrúənu̲s' to the 1st mask '(y̲u̲)' → '(y̲u̲)'
# [L1|D1] Fit 'wobrúənu̲s' with stance [10|10|1]
# [L1|D1] Depth at level 1 increased to 2
# [L0|D0] Fitting 'l' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'l' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 'l' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 'l' with stance [000|000|0]
# [L0|D0] Fitting 'ā' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'ā' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'ā' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'ā' with stance [001|000|0]
# [L0|D0] Breaker count increased to 2
# [L0|D0] Shifted l from [000|000|0] to [010|000|0]
# [L0|D0] Shifted ā from [001|000|0] to [011|000|0]
# [L0|D0] Fitting 'u' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'u' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'u' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'u' with stance [111|000|0]
# [L0|D0] Fitting 'ı' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'ı' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'ı' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'ı' with stance [111|001|0]
# [L0|D0] Inserting w with stance [110|000|0]
# [L1|D2] Fitting 'lāu̲ıw' to the 2nd mask '(y̲u̲)?ı' → '(y̲u̲)?ı'
# [L1|D2] Fitting 'lāu̲ıw' to the 1st mask '(y̲u̲)' → '(y̲u̲)'
# [L1|D2] Fit 'lāu̲ıw' with stance [10|00|2]
# [L0|D0] Fitting 'd' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'd' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 'd' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 'd' with stance [000|000|0]
# [L0|D0] Fitting 'é' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'é' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'é' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'é' with stance [001|000|0]
# [L0|D0] Breaker count increased to 1
# [L0|D0] Shifted d from [000|000|0] to [010|000|0]
# [L0|D0] Shifted é from [001|000|0] to [011|000|0]
# [L0|D0] Fitting 'r' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'r' to the 1st mask '?V̲C' → '?VC̲'
# [L0|D0] Fitting 'r' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 'r' with stance [100|000|0]
# [L0|D0] Fitting 'o' to the 2nd mask '?VC!VC'
# [L0|D0] Inserting ə with stance [101|000|0]
# [L0|D0] Fitting 'o' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'o' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'o' with stance [111|000|0]
# [L0|D0] Inserting w with stance [110|000|0]
# [L1|D2] Fitting 'déəro̲w' to the 1st mask '!(a̲o̲)?e' → '!(a̲o̲)?e'
# [L1|D2] Fitting 'déəro̲w' to the 1st mask '!(a̲o̲)' → '!(a̲o̲)'
# [L1|D2] Fit 'déəro̲w' with stance [00|00|2]
# [L0|D0] Fitting 'n' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'n' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 'n' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 'n' with stance [000|000|0]
# [L0|D0] Fitting 'ō' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'ō' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'ō' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'ō' with stance [001|000|0]
# [L0|D0] Breaker count increased to 2
# [L0|D0] Shifted n from [000|000|0] to [010|000|0]
# [L0|D0] Shifted ō from [001|000|0] to [011|000|0]
# [L0|D0] Fitting 'u' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'u' to the 2nd mask '!V̲C' → '!V̲C'
# [L0|D0] Fitting 'u' to the 1st mask '!V̲' → '!V̲'
# [L0|D0] Fit 'u' with stance [111|000|0]
# [L0|D0] Fitting 's' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 's' to the 2nd mask '!V̲C' → '!VC̲'
# [L0|D0] Fitting 's' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 's' with stance [110|000|0]
# [L1|D2] Fitting 'nōu̲s' to the 2nd mask '(y̲u̲)?ı' → '(y̲u̲)?ı'
# [L1|D2] Fitting 'nōu̲s' to the 1st mask '(y̲u̲)' → '(y̲u̲)'
# [L1|D2] Fit 'nōu̲s' with stance [10|10|2]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 instr = "térsus: lāuı ránom obrúnus: lāuı déro nōus." # "lāuı ránom obrúnus: lāuı déro nōus;; hólos apáurus"
#       2 prc = Processor()
# ----> 3 prc.process(instr, verbose=True)
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:58, in Processor.process(self, instr, verbose)
#      56 # Parsing the string
#      57 try:
# ---> 58     self.streamer.feed()
#      59 except ParsingFailure:
#      60     logger.info(f"Failed to parse '{instr}'")
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:251, in Streamer.feed(self)
#     249 # When the last token is reached, do the closing operations
#     250 if t is None:
# --> 251     self.complete()
#     252     return True
#     253 self.t = t
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:350, in Streamer.complete(self)
#     348 for level in self.prc.levels:
#     349     if level <= self.prc.last_level:
# --> 350         self.pop(level, deep=True)
#     351 self.separate(self.prc.last_level, deep=True)
#     352 return
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:322, in Streamer.pop(self, lvl, deep)
#     320 self.prc.mapping.elems[lvl][-1] = e
#     321 self.prc.mapping.cur_dpt[lvl] -= 1
# --> 322 self.parse()
#     323 dpt = self.prc.mapping.cur_dpt[lvl]
#     324 logger.debug(f"[L{lvl}|D{dpt + 1}] Depth at level {lvl} decreased to {dpt}")
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:379, in Streamer.parse(self)
#     377     num_lvl = lvl - 1 if lvl > self.e.content[0].level else lvl
#     378     self.e.set_head(self.prc.grules.heads[num_lvl], fallback=True)
# --> 379 self.prc.mapper.determine_stance(self.e)
#     380 dpt = self.e.stance.depth
#     381 logger.debug(f"[L{lvl}|D{dpt}] Fit '{self.e}' with stance {self.e.stance}")
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:884, in Mapper.determine_stance(self, e)
#     882 for d in range(0, sum(self.prc.grules.struct[e.level])):
#     883     dich = self.prc.masker.get_dichs(e.stance, e.level)
# --> 884     if not self._decide_dichotomy(dich):
#     885         raise ParsingFailure(f"Failed to parse '{e}'")
#     886 return True
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:560, in Mapper._decide_dichotomy(self, dich, forbid_shift)
#     554 conds = [
#     555     any((not dich.pointer == 1, not dich.ret)),
#     556     any((dich.pointer == 0, not dich.skip)),
#     557 ]
#     558 # Results of fit for the masks
#     559 comps = [
# --> 560     dich.masks[0].compare(self.e, dich.split),
#     561     dich.masks[1].compare(self.e, dich.split),
#     562 ]
#     563 fit = None
#     564 # Skip to the second mask if the breaker count is positive
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_entities.py:270, in Mask.compare(self, e, split, force_mov)
#     259 incr = 1 if (singular or force_mov) and self.active else 0
#     260 while any(
#     261     (
#     262         # Current string, unless the mask is singular and was already fit
#    (...)    268     )
#     269 ):
# --> 270     if self.match(e, incr):
#     271         mov = self.move(incr)
#     272         # Check that we aren't adding compounds beyond the restriction
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_entities.py:294, in Mask.match(self, e, pos, ignore_pos)
#     292 def match(self, e: Element, pos: int = 0, ignore_pos: bool = False) -> bool:
#     293     """Checks if the given string fits the element at the given position."""
# --> 294     head = e.preheader.get_matching_head(e.stance.depth)
#     295     aclass, lit = head.content.base.aclass, head.content.lit
#     296     # If freeze is True, fitting to the mask is forbidden
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_entities.py:429, in Element.get_matching_head(self, depth)
#     427     return self.head
#     428 else:
# --> 429     return self.heads[self.stance.depth - depth]
#
# IndexError: list index out of range

# %%
print(f"Level 1: {prc.get_stances(lvl=1)}")
print(f"Level 0: {prc.get_stances(lvl=0)}")
print(prc.interpreter.draw_tree(0, all_nodes=True))
print(prc.interpreter.draw_tree(1, all_nodes=True))
# Out:
# Level 1: []
# Level 0: [[000|000|0], [000|001|0]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 print(f"Level 1: {prc.get_stances(lvl=1)}")
#       2 print(f"Level 0: {prc.get_stances(lvl=0)}")
# ----> 3 print(prc.interpreter.draw_tree(0, all_nodes=True))
#       4 print(prc.interpreter.draw_tree(1, all_nodes=True))
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:1077, in Interpreter.draw_tree(self, tree, features, all_nodes)
#    1075     tree = self.prc.trees[0][-1]
#    1076 elif isinstance(tree, int):
# -> 1077     tree = self.prc.trees[tree][-1]
#    1079 st = str(tree)
#    1081 if tree.stance:
#
# IndexError: list index out of range

# %%
prc.mapping.elems
# Out:
# [[t,
#   é,
#   ə,
#   r,
#   s,
#   u,
#   s,
#   l,
#   ā,
#   u,
#   ı,
#   w,
#   r,
#   á,
#   ə,
#   n,
#   o,
#   m,
#   w,
#   o,
#   b,
#   r,
#   ú,
#   ə,
#   n,
#   u,
#   s,
#   l,
#   ā,
#   u,
#   ı,
#   w,
#   d,
#   é,
#   ə,
#   r,
#   o,
#   w,
#   n,
#   ō,
#   u,
#   s],
#  [téərsu̲s, [lāu̲ıw, ráəno̲m, wobrúənu̲s], lāu̲ıw·déəro̲w·nōu̲s],
#  []]
