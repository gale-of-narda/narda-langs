# %%
from scripts.parser_procedure import Parser
#from scripts.parser_entities import Tree

# %%
# !pytest -q
# Out:
# ............................F.........FFFFFFFFFFFFFFFFFFFFFFFF           [100%]
# ================================== FAILURES ===================================
# ___________________ test_good_sentences[oeu\u0131u\u0131oe] ___________________
#
# good_string = 'oeuıuıoe'
#
#     @pytest.mark.parametrize("good_string", tests["Sentences"]["good"])
#     def test_good_sentences(good_string):
# >       assert p0.parse(good_string)
# E       AssertionError: assert False
# E        +  where False = parse('oeuıuıoe')
# E        +    where parse = <scripts.parser_procedure.Parser object at 0x000002C0E81EB620>.parse
#
# testing\test_main.py:19: AssertionError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'oeuıuıoe' as 'oeuıuıoe'
# Working with 'o'
# -> Comparing o with first mask '(AO)?E'
# -> Comparing o with first mask '(AO)'
# => Assigned stances [[0, 0], [0, 0]]
# Working with 'e'
# -> Comparing e with first mask '(̲A̲O)?E'
# -> Comparing e with first mask '(̲A̲O)'
# e N(1):  '(̲A̲O)' '?E' 0
# -> Comparing e with second mask '?E'
# => Assigned stances [[0, 1], [0, 0]]
# Working with 'u'
# -> Comparing u with first mask '(AO)?̲E'
# u N(0):  '(AO)?̲E' '(YU)?I' 1
# -> Comparing u with second mask '(YU)?I'
# -> Comparing u with first mask '(YU)'
# => Assigned stances [[1, 0], [0, 0]]
# Working with 'ı'
# -> Comparing ı with first mask '(AO)?E'
# ı N(0):  '(AO)?E' '(̲Y̲U)?I' -1
# -> Comparing ı with second mask '(̲Y̲U)?I'
# -> Comparing ı with first mask '(̲Y̲U)'
# ı N(2):  '(̲Y̲U)' '?I' 0
# -> Comparing ı with second mask '?I'
# => Assigned stances [[1, 1], [0, 0]]
# Working with 'u'
# -> Comparing u with first mask '(AO)?E'
# u N(0):  '(AO)?E' '(YU)?̲I' -1
# -> Comparing u with second mask '(YU)?̲I'
# -> Embedding a compound at N(0):
# -> Comparing u with first mask '(YU)'
# => Assigned stances [[1, 0], [1, 0]]
# Working with 'ı'
# -> Comparing ı with first mask '(AO)?E'
# ı N(0):  '(AO)?E' '(̲Y̲U)?I' -1
# -> Comparing ı with second mask '(̲Y̲U)?I'
# -> Comparing ı with first mask '(YU)'
# ı N(2):  '(YU)' '?̲I' -1
# Failed to match 'ı'
# Could not produce a mapping
# ________________________ test_good_words[hre\u0301ag] _________________________
#
# good_string = 'hréag'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'hréag' as 'hréag'
# Working with 'h'
# -> Comparing h with first mask 'CVCV'
# -> Comparing h with first mask 'CV'
# _____________________________ test_good_words[ar] _____________________________
#
# good_string = 'ar'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ar' as 'ar'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# _____________________________ test_good_words[ra] _____________________________
#
# good_string = 'ra'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ra' as 'ra'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# __________________________ test_good_words[a\u0301r] __________________________
#
# good_string = 'ár'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ár' as 'ár'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# __________________________ test_good_words[ra\u0301] __________________________
#
# good_string = 'rá'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'rá' as 'ra'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# ____________________________ test_good_words[raun] ____________________________
#
# good_string = 'raun'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'raun' as 'raun'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# _________________________ test_good_words[ra\u0301un] _________________________
#
# good_string = 'ráun'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ráun' as 'ráun'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# ____________________________ test_good_words[ara] _____________________________
#
# good_string = 'ara'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ara' as 'ara'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# _________________________ test_good_words[a\u0301ra] __________________________
#
# good_string = 'ára'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ára' as 'ára'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# _________________________ test_good_words[ara\u0301] __________________________
#
# good_string = 'ará'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ará' as 'ara'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# ________________________ test_good_words[ra\u0301erar] ________________________
#
# good_string = 'ráerar'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ráerar' as 'ráerar'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# ________________________ test_good_words[rara\u0301er] ________________________
#
# good_string = 'raráer'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'raráer' as 'raráer'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# _________________________ test_good_words[ra\u0301en] _________________________
#
# good_string = 'ráen'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ráen' as 'ráen'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# ____________________________ test_good_words[nna] _____________________________
#
# good_string = 'nna'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'nna' as 'nna'
# Working with 'n'
# -> Comparing n with first mask 'CVCV'
# -> Comparing n with first mask 'CV'
# ________________________ test_good_words[re\u0301ald] _________________________
#
# good_string = 'réald'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'réald' as 'réald'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# _______________________ test_good_words[rara\u0301arar] _______________________
#
# good_string = 'raráarar'
#
#     @pytest.mark.parametrize("good_string", tests["Words"]["good"])
#     def test_good_words(good_string):
# >       assert p1.parse(good_string)
#                ^^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:28:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'raráarar' as 'raráarar'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# ______________________________ test_bad_words[a] ______________________________
#
# bad_string = 'a'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'a' as 'a'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# ______________________________ test_bad_words[w] ______________________________
#
# bad_string = 'w'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'w' as 'w'
# Working with 'w'
# -> Comparing w with first mask 'CVCV'
# -> Comparing w with first mask 'CV'
# _________________________ test_bad_words[ra\u0301aar] _________________________
#
# bad_string = 'ráaar'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'ráaar' as 'ráaar'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# _________________________ test_bad_words[rae\u0301an] _________________________
#
# bad_string = 'raéan'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'raéan' as 'raéan'
# Working with 'r'
# -> Comparing r with first mask 'CVCV'
# -> Comparing r with first mask 'CV'
# __________________________ test_bad_words[wa\u0301] ___________________________
#
# bad_string = 'wá'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'wá' as 'wa'
# Working with 'w'
# -> Comparing w with first mask 'CVCV'
# -> Comparing w with first mask 'CV'
# __________________________ test_bad_words[a\u0301w] ___________________________
#
# bad_string = 'áw'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'áw' as 'áw'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# __________________________ test_bad_words[akakakak] ___________________________
#
# bad_string = 'akakakak'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[1, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[1, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'akakakak' as 'akakakak'
# Working with 'a'
# -> Comparing a with first mask 'CVCV'
# a N(0):  'CVCV' 'VCVC' -1
# -> Comparing a with second mask 'VCVC'
# -> Comparing a with first mask 'VC'
# __________________________ test_bad_words[kakakaka] ___________________________
#
# bad_string = 'kakakaka'
#
#     @pytest.mark.parametrize("bad_string", tests["Words"]["bad"])
#     def test_bad_words(bad_string):
# >       assert not p1.parse(bad_string)
#                    ^^^^^^^^^^^^^^^^^^^^
#
# testing\test_main.py:32:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# scripts\parser_procedure.py:352: in parse
#     general = self._produce(pst)
#               ^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:320: in _produce
#     stances = self._process_char(c)
#               ^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:230: in _process_char
#     matches = self._match_char(s, d, node, stances)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# scripts\parser_procedure.py:179: in _match_char
#     binrank, binnum = self._get_bins(stances[0], 2**r - 1)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <scripts.parser_procedure.Parser object at 0x000002C0E8265450>
# stances = [[0, 0]], stop = 1
#
#     def _get_bins(self, stances: List[int], stop: int) -> Tuple[int, int]:
#         struct = self.buff.tree.struct
#         lst = [r == 0 for s in struct for r in range(s)]
#         fstances = [p for i, p in enumerate(stances) if lst[i]][:stop]
#         binrank = len(fstances)
# >       binnum = int("".join(str(s) for s in fstances) or "0", 2)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       ValueError: invalid literal for int() with base 2: '[0, 0]'
#
# scripts\parser_procedure.py:137: ValueError
# ---------------------------- Captured stdout call -----------------------------
# Parsing string 'kakakaka' as 'kakakaka'
# Working with 'k'
# -> Comparing k with first mask 'CVCV'
# -> Comparing k with first mask 'CV'
# =========================== short test summary info ===========================
# FAILED testing/test_main.py::test_good_sentences[oeu\u0131u\u0131oe] - AssertionError: assert False
# FAILED testing/test_main.py::test_good_words[hre\u0301ag] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[ar] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_good_words[ra] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[a\u0301r] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_good_words[ra\u0301] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[raun] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[ra\u0301un] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[ara] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_good_words[a\u0301ra] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_good_words[ara\u0301] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_good_words[ra\u0301erar] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[rara\u0301er] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[ra\u0301en] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[nna] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[re\u0301ald] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_good_words[rara\u0301arar] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_bad_words[a] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_bad_words[w] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_bad_words[ra\u0301aar] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_bad_words[rae\u0301an] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_bad_words[wa\u0301] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# FAILED testing/test_main.py::test_bad_words[a\u0301w] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_bad_words[akakakak] - ValueError: invalid literal for int() with base 2: '[1, 0]'
# FAILED testing/test_main.py::test_bad_words[kakakaka] - ValueError: invalid literal for int() with base 2: '[0, 0]'
# 25 failed, 37 passed in 0.58s

# %%
input_string = "oeoe"
p = Parser()
p.load_params(level=0)
res = p.parse(input_string)
print(res, p.buff.tree)
# Out:
# Parsing string 'oeoe' as 'oeoe'
# Working with 'o'
# -> Comparing o with first mask '(AO)?E'
# -> Comparing o with first mask '(AO)'
# => Assigned stances [[0, 0], [0, 0]]
# Working with 'e'
# -> Comparing e with first mask '(̲A̲O)?E'
# -> Comparing e with first mask '(̲A̲O)'
# e N(1):  '(̲A̲O)' '?E' 0
# -> Comparing e with second mask '?E'
# => Assigned stances [[0, 1], [0, 0]]
# Working with 'o'
# -> Comparing o with first mask '(AO)?̲E'
# -> Embedding a compound at N(0):
# -> Comparing o with first mask '(AO)'
# => Assigned stances [[0, 0], [1, 0]]
# Working with 'e'
# -> Comparing e with first mask '(̲A̲O)?E'
# -> Comparing e with first mask '(AO)'
# e N(1):  '(AO)' '?̲E' -1
# Failed to match 'e'
# Could not produce a mapping
# False T[1, 1]
# └─N(0):
#   ├─N(1):
#     ⤷─N(0):
#       ├─N(1):
#       └─N(2):
#   │ ├─N(3):
#   │ └─N(4):
#   └─N(2):
#     ├─N(5):
#     └─N(6):

# %%
p.buff.tree.nodes[1].content[0].masks
# Out:
# [['(̲A̲O)', '?E']]
