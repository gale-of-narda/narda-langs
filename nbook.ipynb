# %%
import logging

from scripts.parser_procedure import Processor
# from scripts.parser_entities import Tree, Element
# from scripts.parser_dataclasses import Symbol, Token

logging.basicConfig(level="DEBUG", format="%(message)s", datefmt="[%X]")

# %%
instr = "hréag."
prc = Processor(max_level=0)
prc.process(instr, verbose=True)
# Out:
# Parsing 'hréag.'
# [L0|D0] Fitting 'h' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'h' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 'h' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 'h' with stance [000|000|0]
# [L0|D0] Fitting 'r' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'r' to the 1st mask '?C̲V' → '?C̲V'
# [L0|D0] Fitting 'r' to the 1st mask '?C̲' → '?C̲'
# [L0|D0] Fit 'r' with stance [000|001|0]
# [L0|D0] Fitting 'é' to the 1st mask '?CVCV'
# [L0|D0] Fitting 'é' to the 1st mask '?C̲V' → '?CV̲'
# [L0|D0] Fitting 'é' to the 2nd mask 'V̲' → 'V̲'
# [L0|D0] Fit 'é' with stance [001|000|0]
# [L0|D0] Breaker count increased to 1
# Closing dich '?CVCV'—'?VC!VC'
# [L0|D0] Shifted h from [000|000|0] to [010|000|0]
# [L0|D0] Shifted r from [000|001|0] to [010|001|0]
# [L0|D0] Shifted é from [001|000|0] to [011|000|0]
# Filling '?C'—'V' with l={},r={}
# Neutralizing on level 0 at []
# Filling 'C'—'V̲' with l={'00': [0, 1]},r={'00': [2]}
# Neutralizing on level 0 at []
# [L0|D0] Fitting 'a' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'a' to the 1st mask '?V̲C' → '?V̲C'
# [L0|D0] Fitting 'a' to the 1st mask '?V̲' → '?V̲'
# [L0|D0] Fit 'a' with stance [101|000|0]
# [L0|D0] Fitting 'g' to the 2nd mask '?VC!VC'
# [L0|D0] Fitting 'g' to the 1st mask '?V̲C' → '?VC̲'
# [L0|D0] Fitting 'g' to the 2nd mask 'C̲' → 'C̲'
# [L0|D0] Fit 'g' with stance [100|000|0]
# Closing element hréag
# Closing dich '?CVCV'—'?VC!VC'
# Filling '?V'—'C̲' with l={'00': [3]},r={'00': [4]}
# Neutralizing on level 0 at []
# Filling '!V'—'C' with l={},r={}
# Neutralizing on level 0 at [([4], '!V', [110|000|0])]
# [L0|D0] Inserting u with stance [111|000|0]
# Neutralizing on level 0 at [([5], 'C', [111|000|0])]
# [L0|D0] Inserting w with stance [110|000|0]
# Successfully parsed 'hréag.'
# True

# %%
print(f"Level 1: {prc.get_stances(lvl=1)}")
print(f"Level 0: {prc.get_stances(lvl=0)}")
print(prc.interpreter.draw_tree(0, all_nodes=True))
print(prc.interpreter.draw_tree(1, all_nodes=True))
# Out:
# Level 1: [[||0]]
# Level 0: [[010|000|0], [010|001|0], [011|000|0], [101|000|0], [100|000|0], [111|000|0], [110|000|0]]
# T[2, 1]: Content word
# └─N(0): hréaguw
#   └─N(1):
#   │ └─N(5):
#   │ └─N(6):
#   └─N(2): hré
#   │ └─N(7): h
#   │ ⤷─N(7): r
#   │ └─N(8): é
#   └─N(3): ag
#   │ └─N(9): g
#   │ └─N(10): a
#   └─N(4): uw
#     └─N(11): w
#     └─N(12): u
#
# T[1, 1]: Undefined composition type
# └─N(0): hréaguw
#   └─N(1):
#   │ └─N(3):
#   │ └─N(4):
#   └─N(2):
#     └─N(5):
#     └─N(6):
