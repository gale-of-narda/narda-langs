# %%
from scripts.parser_procedure import Parser
#from scripts.parser_entities import Tree

# %%
input_string = 'ue'
parser = Parser(level=0)
res = parser.parse(input_string)
# Out:
# Parsing 'ue' as 'ue'
# Working with 'u'
# -> Comparing u with second mask '(YU)?I'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 input_string = 'ue'
#       2 parser = Parser(level=0)
# ----> 3 res = parser.parse(input_string)
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:248, in Parser.parse(self, input_string)
#     245 print(f"Parsing '{input_string}' as '{parsed_string}'")
#     247 # Apply general rules to produce the mapping
# --> 248 self.buffer.mapping = self.produce_mapping(parsed_string)
#     249 if self.buffer.mapping:
#     250     self.shift_nonbinary_mappings()
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:270, in Parser.produce_mapping(self, prep_string)
#     268 for char in prep_string:
#     269     print(f"Working with '{char}'")
# --> 270     stance = self.determine_char_stance(char)
#     271     print('determined')
#     272     if stance is False:
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:390, in Parser.determine_char_stance(self, char)
#     388 stance = ([], [])
#     389 for d in range(len(self.masker.masks)):
# --> 390     decision = self.decide_dichotomy(char, stance)
#     391     if type(decision) is bool:
#     392         return decision
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:428, in Parser.decide_dichotomy(self, cand, stance)
#     424 second_cond = any(
#     425     [first_mask.pos is not None, second_mask.pos is not None, not skip]
#     426 )
#     427 first_comp = self.compare_with_mask(cand, first_mask, split)
# --> 428 second_comp = self.compare_with_mask(cand, second_mask, split)
#     430 if first_cond and first_comp:
#     431     print(f"-> Comparing {cand} with first mask {first_mask}")
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_procedure.py:466, in Parser.compare_with_mask(self, cand, mask, split)
#     455 # Otherwise start going throgh the literals one-by-one
#     456 while any(
#     457     [
#     458         # Current char, unless the mask is singular and was already fit
#    (...)    464     ]
#     465 ):
# --> 466     if mask.match(rep, incr):
#     467         mov = mask.move(incr)
#     468         # Check that we aren't adding compounds beyond the restriction
#
# File c:\Users\Nadir\Desktop\Lang\narda-langs\scripts\parser_entities.py:86, in Mask.match(self, rep, pos, ignore_pos)
#      83     else:
#      84         return (new_pos, new_rep)
# ---> 86 def match(self, rep: str, pos: int = 0, ignore_pos: bool = False) -> bool:
#      87     if ignore_pos:
#      88         return any([rep in m for pos in self.literals for m in pos])
#
# KeyboardInterrupt:
