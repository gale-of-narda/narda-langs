# %%
from scripts.parser_procedure import Processor
#from scripts.parser_entities import Tree, Element
#from scripts.parser_dataclasses import Symbol, Token

# %%
instr = "mórta mánus: lāoı hólo."
prc = Processor()
prc.process(instr, verbose=True)
# Out:
# [INFO] Parsing mórta mánus: lāoı hólo.
# [DEBUG] -> Fitting m to the 1st mask '?CVCV'
# [DEBUG] -> Fitting m to the 1st mask '?C̲V' → '?C̲V'
# [DEBUG] -> Fitting m to the 1st mask '?C̲' → '?C̲'
# [DEBUG] => Assigned the stance [000|000|0] to m
# [DEBUG] -> Fitting ó to the 1st mask '?CVCV'
# [DEBUG] -> Fitting ó to the 1st mask '?C̲V' → '?CV̲'
# [DEBUG] -> Fitting ó to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [001|000|0] to ó
# [DEBUG] -> Breaker count at level 0, depth 0 increased to 1
# [DEBUG] -> Shifted m from [000|000|0] to [010|000|0]
# [DEBUG] -> Shifted ó from [001|000|0] to [011|000|0]
# [DEBUG] -> Fitting r to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting r to the 1st mask '?V̲C' → '?VC̲'
# [DEBUG] -> Fitting r to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [100|000|0] to r
# [DEBUG] -> Fitting t to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting t to the 1st mask '?VC̲' → '?VC̲'
# [DEBUG] -> Fitting t to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [100|001|0] to t
# [DEBUG] -> Fitting a to the 2nd mask '?VCVC'
# [DEBUG] -> Inserting ə with stance [101|000|0]
# [DEBUG] -> Fitting a to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting a to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|000|0] to a
# [DEBUG] -> Inserting w with stance [110|000|0]
# [DEBUG] -> Fitting a to the 1st mask '(a̲o̲)?e' → '(a̲o̲)?e'
# [DEBUG] -> Fitting a to the 1st mask '(a̲o̲)' → '(a̲o̲)'
# [DEBUG] => Assigned the stance [00|00|0] to móərta̲w
# [DEBUG] -> Fitting m to the 1st mask '?CVCV'
# [DEBUG] -> Fitting m to the 1st mask '?C̲V' → '?C̲V'
# [DEBUG] -> Fitting m to the 1st mask '?C̲' → '?C̲'
# [DEBUG] => Assigned the stance [000|000|0] to m
# [DEBUG] -> Fitting á to the 1st mask '?CVCV'
# [DEBUG] -> Fitting á to the 1st mask '?C̲V' → '?CV̲'
# [DEBUG] -> Fitting á to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [001|000|0] to á
# [DEBUG] -> Breaker count at level 0, depth 0 increased to 1
# [DEBUG] -> Shifted m from [000|000|0] to [010|000|0]
# [DEBUG] -> Shifted á from [001|000|0] to [011|000|0]
# [DEBUG] -> Fitting n to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting n to the 1st mask '?V̲C' → '?VC̲'
# [DEBUG] -> Fitting n to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [100|000|0] to n
# [DEBUG] -> Fitting u to the 2nd mask '?VCVC'
# [DEBUG] -> Inserting ə with stance [101|000|0]
# [DEBUG] -> Fitting u to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting u to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|000|0] to u
# [DEBUG] -> Fitting s to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting s to the 2nd mask 'V̲C' → 'VC̲'
# [DEBUG] -> Fitting s to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [110|000|0] to s
# [DEBUG] -> Fitting u to the 2nd mask '(y̲u̲)?ı' → '(y̲u̲)?ı'
# [DEBUG] -> Fitting u to the 1st mask '(y̲u̲)' → '(y̲u̲)'
# [DEBUG] => Assigned the stance [10|00|0] to máənu̲s
# [DEBUG] -> Depth at level 1 increased to 1
# [DEBUG] -> Fitting l to the 1st mask '?CVCV'
# [DEBUG] -> Fitting l to the 1st mask '?C̲V' → '?C̲V'
# [DEBUG] -> Fitting l to the 1st mask '?C̲' → '?C̲'
# [DEBUG] => Assigned the stance [000|000|0] to l
# [DEBUG] -> Fitting ā to the 1st mask '?CVCV'
# [DEBUG] -> Fitting ā to the 1st mask '?C̲V' → '?CV̲'
# [DEBUG] -> Fitting ā to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [001|000|0] to ā
# [DEBUG] -> Breaker count at level 0, depth 0 increased to 2
# [DEBUG] -> Shifted l from [000|000|0] to [010|000|0]
# [DEBUG] -> Shifted ā from [001|000|0] to [011|000|0]
# [DEBUG] -> Fitting o to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting o to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting o to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|000|0] to o
# [DEBUG] -> Fitting ı to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting ı to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting ı to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|001|0] to ı
# [DEBUG] -> Inserting w with stance [110|000|0]
# [DEBUG] -> Fitting o to the 1st mask '(a̲o̲)?e' → '(a̲o̲)?e'
# [DEBUG] -> Fitting o to the 1st mask '(a̲o̲)' → '(a̲o̲)'
# [DEBUG] => Assigned the stance [00|00|1] to lāo̲ıw
# [DEBUG] -> Fitting h to the 1st mask '?CVCV'
# [DEBUG] -> Fitting h to the 1st mask '?C̲V' → '?C̲V'
# [DEBUG] -> Fitting h to the 1st mask '?C̲' → '?C̲'
# [DEBUG] => Assigned the stance [000|000|0] to h
# [DEBUG] -> Fitting ó to the 1st mask '?CVCV'
# [DEBUG] -> Fitting ó to the 1st mask '?C̲V' → '?CV̲'
# [DEBUG] -> Fitting ó to the 2nd mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [001|000|0] to ó
# [DEBUG] -> Breaker count at level 0, depth 0 increased to 1
# [DEBUG] -> Shifted h from [000|000|0] to [010|000|0]
# [DEBUG] -> Shifted ó from [001|000|0] to [011|000|0]
# [DEBUG] -> Fitting l to the 2nd mask '?VCVC'
# [DEBUG] -> Fitting l to the 1st mask '?V̲C' → '?VC̲'
# [DEBUG] -> Fitting l to the 2nd mask 'C̲' → 'C̲'
# [DEBUG] => Assigned the stance [100|000|0] to l
# [DEBUG] -> Fitting o to the 2nd mask '?VCVC'
# [DEBUG] -> Inserting ə with stance [101|000|0]
# [DEBUG] -> Fitting o to the 2nd mask 'V̲C' → 'V̲C'
# [DEBUG] -> Fitting o to the 1st mask 'V̲' → 'V̲'
# [DEBUG] => Assigned the stance [111|000|0] to o
# [DEBUG] -> Inserting w with stance [110|000|0]
# [DEBUG] -> Fitting o to the 1st mask '(a̲o̲)?e' → '(a̲o̲)?e'
# [DEBUG] -> Fitting o to the 1st mask '(a̲o̲)' → '(a̲o̲)'
# [DEBUG] => Assigned the stance [00|01|1] to hóəlo̲w
# [DEBUG] -> Fitting lāo̲ıw to the 2nd mask '(y̲u̲)?ı' → '(yu)?ı̲'
# [DEBUG] -> Fitting lāo̲ıw to the 2nd mask '?ı̲' → '?ı̲'
# [DEBUG] => Assigned the stance [11|00|0] to lāo̲ıw·hóəlo̲w
# [DEBUG] -> Depth at level 1 decreased to 0
# [INFO] Successfully parsed mórta mánus: lāoı hólo. as [móərta̲w, máənu̲s, lāo̲ıw·hóəlo̲w]
# [DEBUG] Embedded a complex at N(6):
# True

# %%
print(f"Level 1: {prc.get_stances(lvl=1)}")
print(f"Level 0: {prc.get_stances(lvl=0)}")
prc.interpreter.draw_tree(0, all_nodes=True)
prc.interpreter.draw_tree(1, all_nodes=True)
# Out:
# Level 1: [[00|00|0], [10|00|0], [11|00|0]]
# Level 0: [[010|000|0], [011|000|0], [101|000|0], [100|000|0], [100|001|0], [111|000|0], [110|000|0], [010|000|0], [011|000|0], [101|000|0], [100|000|0], [111|000|0], [110|000|0], [010|000|0], [011|000|0], [111|000|0], [111|001|0], [110|000|0], [010|000|0], [011|000|0], [101|000|0], [100|000|0], [111|000|0], [110|000|0]]
# T[2, 1]: Proform
# └─N(0): lāoıw
#   └─N(1):
#   │ └─N(5):
#   │ └─N(6):
#   └─N(2): lā
#   │ └─N(7): l
#   │ └─N(8): ā
#   └─N(3):
#   │ └─N(9):
#   │ └─N(10):
#   └─N(4): oıw
#     └─N(11): w
#     └─N(12): o
#     ⤷─N(12): ı
#
# T[1, 1]: Full sentence
# └─N(0): móərta̲w máənu̲s lāo̲ıw
#   └─N(1): móərta̲w
#   │ └─N(3): móərta̲w
#   │ └─N(4):
#   └─N(2): máənu̲s lāo̲ıw
#     └─N(5): máənu̲s
#     └─N(6): lāo̲ıw
#     ⤷─T[1, 1]: Predicate-only
#         └─N(0): lāo̲ıw hóəlo̲w
#           └─N(1): lāo̲ıw hóəlo̲w
#           │ └─N(3): lāo̲ıw
#           │ ⤷─N(3): hóəlo̲w
#           │ └─N(4):
#           └─N(2):
#             └─N(5):
#             └─N(6):
